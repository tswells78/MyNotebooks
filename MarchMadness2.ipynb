# %% [markdown]
# <a href="https://colab.research.google.com/github/tswells78/MyNotebooks/blob/master/MarchMadness2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
try:
  from sportsreference.ncaab.teams import Teams
except ModuleNotFoundError:
  # !pip install sportsreference
  from sportsreference.ncaab.teams import Teams
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

FIELDS_TO_DROP = ['away_points', 'home_points', 'date', 'location',
                  'losing_abbr', 'losing_name', 'winner', 'winning_abbr',
                  'winning_name', 'home_ranking', 'away_ranking']

dataset = pd.DataFrame()
teams = Teams()
count = 0

# %%
  for team in teams:
      count += 1
      if count == 20:
        break
      else:
        dataset = pd.concat([dataset, team.schedule.dataframe_extended])

# %%
dataset
# Out:
#                                   away_assist_percentage  ...        winning_name
# 2019-11-05-20-abilene-christian                     25.0  ...   Abilene Christian
# 2019-11-10-14-drexel                                43.3  ...              Drexel
# 2019-11-16-20-abilene-christian                     39.1  ...          Pepperdine
# 2019-11-18-22-nevada-las-vegas                      72.7  ...                UNLV
# 2019-11-21-12-abilene-christian                     43.8  ...   Abilene Christian
# 2019-11-25-20-texas-state                           36.8  ...         Texas State
# 2019-11-29-20-southern-methodist                    47.1  ...                 SMU
# 2019-12-05-20-abilene-christian                     31.6  ...   Abilene Christian
# 2019-12-07-20-abilene-christian                     25.0  ...   Abilene Christian
# 2019-12-12-19-abilene-christian                     33.3  ...   Abilene Christian
# 2019-12-18-20-new-orleans                           75.0  ...   Abilene Christian
# 2019-12-21-20-abilene-christian                     22.2  ...   Abilene Christian
# 2019-11-07-21-air-force                             46.4  ...         Idaho State
# 2019-11-09-16-air-force                             31.0  ...           Air Force
# 2019-11-12-19-army                                  47.8  ...           Air Force
# 2019-11-18-21-texas-christian                       75.0  ...                 TCU
# 2019-11-21-16-loyola-marymount                      73.7  ...    Loyola Marymount
# 2019-11-22-18-air-force                             53.6  ...            Duquesne
# 2019-11-24-16-indiana-state                         40.0  ...       Indiana State
# 2019-12-01-16-air-force                             60.0  ...           Air Force
# 2019-12-04-21-wyoming                               65.6  ...           Air Force
# 2019-12-07-14-air-force                             50.0  ...              Nevada
# 2019-12-14-15-denver                                60.0  ...           Air Force
# 2019-12-17-21-air-force                             66.7  ...           Air Force
# 2019-12-21-14-air-force                             64.5  ...               Drake
# 2019-11-05-19-akron                                 20.0  ...               Akron
# 2019-11-08-19-west-virginia                         54.2  ...       West Virginia
# 2019-11-15-19-akron                                 23.5  ...               Akron
# 2019-11-18-19-akron                                 16.7  ...               Akron
# 2019-11-21-19-akron                                 31.8  ...               Akron
# 2019-11-24-18-louisville                            48.1  ...          Louisville
# 2019-11-29-19-akron                                 35.0  ...               Akron
# 2019-12-04-19-marshall                              53.6  ...               Akron
# 2019-12-08-14-akron                                 50.0  ...               Akron
# 2019-12-15-14-akron                                 27.8  ...               Akron
# 2019-12-20-14-tulane                                81.0  ...               Akron
# 2019-12-21-15-liberty                               54.2  ...             Liberty
# 2019-11-05-20-tennessee-state                       29.2  ...     Tennessee State
# 2019-11-11-20-alabama-birmingham                    22.7  ...  Alabama-Birmingham
# 2019-11-14-19-cincinnati                            47.6  ...          Cincinnati
# 2019-11-16-12-miami-oh                              43.5  ...          Miami (OH)
# 2019-11-21-19-clemson                               42.1  ...             Clemson
# 2019-11-25-20-alabama-am                            65.2  ...         Alabama A&M
# 2019-12-07-17-alabama-am                            42.3  ...         Alabama A&M
# 2019-12-14-14-miami-fl                              64.5  ...          Miami (FL)
# 2019-12-17-20-south-alabama                         29.6  ...       South Alabama
# 2019-12-20-19-alabama-am                            50.0  ...         Alabama A&M
# 2019-11-05-20-abilene-christian                     25.0  ...   Abilene Christian
# 2019-11-10-14-drexel                                43.3  ...              Drexel
# 2019-11-16-20-abilene-christian                     39.1  ...          Pepperdine
# 2019-11-18-22-nevada-las-vegas                      72.7  ...                UNLV
# 2019-11-21-12-abilene-christian                     43.8  ...   Abilene Christian
# 2019-11-25-20-texas-state                           36.8  ...         Texas State
# 2019-11-29-20-southern-methodist                    47.1  ...                 SMU
# 2019-12-05-20-abilene-christian                     31.6  ...   Abilene Christian
# 2019-12-07-20-abilene-christian                     25.0  ...   Abilene Christian
# 2019-12-12-19-abilene-christian                     33.3  ...   Abilene Christian
# 2019-12-18-20-new-orleans                           75.0  ...   Abilene Christian
# 2019-12-21-20-abilene-christian                     22.2  ...   Abilene Christian
#
# [59 rows x 86 columns]

# %%
X = dataset.drop(FIELDS_TO_DROP, 1).dropna().drop_duplicates()
y = dataset[['home_points', 'away_points']].values
X_train, X_test, y_train, y_test = train_test_split(X, y)
parameters = {'bootstrap': False,
              'min_samples_leaf': 3,
              'n_estimators': 50,
              'min_samples_split': 10,
              'max_features': 'sqrt',
              'max_depth': 6}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0b3aee32467d> in <module>()
#       1 X = dataset.drop(FIELDS_TO_DROP, 1).dropna().drop_duplicates()
#       2 y = dataset[['home_points', 'away_points']].values
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y)
#       4 parameters = {'bootstrap': False,
#       5               'min_samples_leaf': 3,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2094         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2095
# -> 2096     arrays = indexable(*arrays)
#    2097
#    2098     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     228         else:
#     229             result.append(np.array(X))
# --> 230     check_consistent_length(*result)
#     231     return result
#     232
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [47, 59]

# %%
model = RandomForestRegressor(**parameters)
model.fit(X_train, y_train)
print(model.predict(X_test).astype(int), y_test)
# Out:
# [[81 71]
#  [81 56]
#  [71 61]
#  [89 52]
#  [81 55]
#  [81 79]
#  [72 58]
#  [71 62]
#  [87 53]
#  [78 77]
#  [92 51]
#  [72 55]] [[ 80  66]
#  [ 74  52]
#  [ 67  62]
#  [100  50]
#  [ 76  52]
#  [ 71  77]
#  [ 82  60]
#  [ 57  69]
#  [ 90  39]
#  [ 63  69]
#  [102  34]
#  [ 76  45]]
